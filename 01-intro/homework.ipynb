# %%
import numpy as np
import pandas as pd

# %%
# Q1. Pandas version
pd.__version__
# Out:
# '3.0.5'

# %%
df=pd.read_csv('car_fuel_efficiency_2026.csv')
df.head(3)
# Out:
#    model_year  origin fuel_type         drivetrain  num_doors  \
# 0        2006  Europe  Gasoline  Front-wheel drive          4
# 1        2008  Europe    Diesel  Front-wheel drive          4
# 2        1996    Asia  Gasoline  Front-wheel drive          5
#
#    engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                 2180              6       243.0            3870
# 1                 2390              6       272.0            4210
# 2                 2320              6       267.0            4240
#
#    acceleration  fuel_efficiency_mpg
# 0           NaN                 31.9
# 1           NaN                 31.3
# 2          17.3                 27.5

# %%
# Q2. How many records are in the dataset?
df.shape
# Out:
# (10000, 11)

# %%
# Q3. How many fuel types are presented in the dataset?
df.fuel_type.nunique()
# Out:
# 3

# %%
# Q4. How many columns in the dataset have missing values?
df.columns[df.isna().sum()>0]
# Out:
# Index(['horsepower', 'acceleration'], dtype='str')

# %%
# Q5. What's the maximum fuel efficiency of cars from Asia?
df.groupby('origin')['fuel_efficiency_mpg'].max()
# Out:
# origin
# Asia      41.2
# Europe    39.4
# USA       38.2
# Name: fuel_efficiency_mpg, dtype: float64

# %%
# Q6. Find the median value of the horsepower column in the dataset. 
# Next, calculate the most frequent value of the same horsepower column.
# Use the fillna method to fill the missing values in the horsepower column with the most frequent value from the previous step.
# Now, calculate the median value of horsepower once again.
# Has it changed?

before_median=df.horsepower.median()

mode=df.horsepower.mode()[0]

df.horsepower=df.horsepower.fillna(mode)
after_median=df.horsepower.median()

print(before_median,after_median)
# Out:
# 254.0 252.0

# %%
# Q7. Sum of weights
# Select all the cars from Asia
# Select only columns vehicle_weight and model_year
# Select the first 7 values
# Get the underlying NumPy array. Let's call it X.
# Compute matrix-matrix multiplication between the transpose of X and X. To get the transpose, use X.T. Let's call the result XTX.
# Invert XTX.
# Create an array y with values [1100, 1300, 800, 900, 1000, 1100, 1200].
# Multiply the inverse of XTX with the transpose of X, and then multiply the result by y. Call the result w.
# What's the sum of all the elements of the result?


cars_from_asia=df[df.origin=='Asia']
cars_from_asia=cars_from_asia[['vehicle_weight','model_year']].head(7) #Importante ponerle los 2 corchetes porque el está preparado para leer una lista
X=cars_from_asia.to_numpy()


XTX=X.T @ X
XTX_inv=np.linalg.inv(XTX)

y=np.array([1100, 1300, 800, 900, 1000, 1100, 1200])
w=XTX_inv @ X.T @ y
sum_of_weights=w.sum()
print(sum_of_weights)
# Out:
# 0.36919696904925486
